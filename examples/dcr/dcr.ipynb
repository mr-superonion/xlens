# %%
# %pylab inline
# %reload_ext autoreload
# %autoreload 2

import os

import astropy.table as astable
import fitsio
# Out:
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib

# %%
config_fname = "./config.ini"
from xlens.simulation.simulator.base import SimulateImageDCR


def distort_func(x, y):
    return x + 1, y + 1


simulator = SimulateImageDCR(config_fname)
simulator.run(ifield=1, distort_func=distort_func)
image = fitsio.read("sim/image-00001_r.fits")
# Out:
# Simulation has galaxies: 1459

# %%
plt.close()
plt.imshow(image)

# %%
def distort_func(x, y):
    return x + 20, y


simulator = SimulateImageDCR(config_fname)
simulator.run(ifield=1, distort_func=distort_func)
image = fitsio.read("sim/image-00001_r.fits")
# Out:
# Simulation has galaxies: 1459

# %%
plt.close()
plt.imshow(image)
