# %%
import matplotlib.pyplot as plt

plt.style.use("MNRAS")

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
anacal_shear = np.array(
    [
        0.00397153,
        -0.02175738,
        -0.02148741,
        -0.02439542,
        -0.02667179,
        -0.02399448,
        -0.02572193,
        -0.02071802,
        -0.0189025,
        -0.01858847,
    ]
)
true_shear = np.array(
    [
        -0.03771292,
        -0.02892669,
        -0.02317557,
        -0.01906895,
        -0.01602246,
        -0.01369343,
        -0.01186802,
        -0.01040716,
        -0.00921723,
        -0.00823322,
    ]
)

# Plot
plt.figure(figsize=(8, 8))
plt.plot(-true_shear, -anacal_shear, "o-", label="Anacal Shear vs True Shear")

# Labels and title
plt.xlabel("True Shear (gt)")
plt.ylabel("Anacal Shear")
plt.title("Anacal Shear vs True Shear")
plt.grid(True)
plt.legend()
plt.xlim(0.04, -0.01)
plt.ylim(0.04, -0.01)
plt.plot([0.04, -0.01], [0.04, -0.01], "k--")

# Display plot
plt.show()
